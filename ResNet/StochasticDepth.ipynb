# %%
# model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim 
from torch.optim.lr_scheduler import StepLR

# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os

# display images
from torchvision import utils
import matplotlib.pyplot as plt

# utils
import numpy as np
import time
import copy

os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
# GPU 사용 가능 여부 확인
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# GPU 이름 출력
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# Load Dataset : STL10
# specify the data path
path2data = './rdata'

# if not exists the path, make the directory
if not os.path.exists(path2data):
    os.mkdir(path2data)

# load dataset
train_ds = datasets.STL10(path2data, split='train', download=True, transform=transforms.ToTensor()) # 5000장
val_ds = datasets.STL10(path2data, split='test',download=True, transform=transforms.ToTensor()) # 8000장

print(len(train_ds))
print(len(val_ds))
# Out:
# Using device: cuda
# GPU: NVIDIA TITAN Xp
# Files already downloaded and verified
# Files already downloaded and verified
# 5000
# 8000

# %%
# caculate mean & std
# dataset : caculate mean & std
# to normalize the dataset, calculate the mean and std
train_meanRGB = [np.mean(x.numpy(), axis=(1,2)) for x, _ in train_ds]
train_stdRGB = [np.std(x.numpy(), axis=(1,2)) for x, _ in train_ds]

train_meanR = np.mean([m[0] for m in train_meanRGB])
train_meanG = np.mean([m[1] for m in train_meanRGB])
train_meanB = np.mean([m[2] for m in train_meanRGB])
train_stdR = np.mean([s[0] for s in train_stdRGB])
train_stdG = np.mean([s[1] for s in train_stdRGB])
train_stdB = np.mean([s[2] for s in train_stdRGB])

val_meanRGB = [np.mean(x.numpy(), axis=(1,2)) for x, _ in val_ds]
val_stdRGB = [np.std(x.numpy(), axis=(1,2)) for x, _ in val_ds]

val_meanR = np.mean([m[0] for m in val_meanRGB])
val_meanG = np.mean([m[1] for m in val_meanRGB])
val_meanB = np.mean([m[2] for m in val_meanRGB])

val_stdR = np.mean([s[0] for s in val_stdRGB])
val_stdG = np.mean([s[1] for s in val_stdRGB])
val_stdB = np.mean([s[2] for s in val_stdRGB])

print(train_meanR, train_meanG, train_meanB)
print(val_meanR, val_meanG, val_meanB)
# Out:
# 0.4467106 0.43980986 0.40664646
# 0.44723064 0.4396425 0.40495726

# %%
# define the image transformation 
train_transformation = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(224), # ResNet이 224x224로 설계가 되어있기 때문이다. -> 최종적으로 1x1로 딱 떨어지게 됨(원래 원본은 96)
    transforms.Normalize([train_meanR, train_meanG, train_meanB], [train_stdR, train_stdG, train_stdB]),
    transforms.RandomHorizontalFlip()
])

val_transformation = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize(224),
    transforms.Normalize([train_meanR, train_meanG, train_meanB], [train_stdR, train_stdG, train_stdB]),
])

# apply transformation
train_ds.transform = train_transformation
val_ds.transform = val_transformation

# create DataLoader
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=32, shuffle=False)

# %%
# image grid display
def show(img, y=None, color=True): # y:label
    npimg = img.numpy() # tensor -> numpy
    npimg_tr = np.transpose(npimg, (1,2,0)) # 차원 순서 변경(Pytorch의 경우 : [C,H,W], matplotlib의 경우 : [H,W,C])
    plt.imshow(npimg_tr) # 이미지 화면에 표시

    if y is not None: # 라벨이 있을 때만 실행
        plt.title('labels: '+ str(y)) # 이미지 위에 라벨 표시

# 랜덤 고정(매번 같은 이미지 선택 - 재현성)
np.random.seed(1) # numpy 랜덤 고정
torch.manual_seed(1) # pytorch 랜덤 고정

# train_dataset에서 8개 데이터 랜덤하게 선정
grid_size=8
rnd_inds = np.random.randint(0, len(train_ds), grid_size) # 0~5000 사이에서 랜덤하게 8개 인덱스 선택
print('image indices: ', rnd_inds)

# 샘플 이미지와 라벨 추출(train_ds[i]는 튜플이라 train_ds[i][0] : 이미지, train_ds[i][1] : 라벨)
x_grid = [train_ds[i][0] for i in rnd_inds] # 데이터셋 : 이미지 데이터 8개
y_grid = [train_ds[i][1] for i in rnd_inds] # 데이터셋 : 라벨 8개

# 그리드 생성 및 출력
# 8개 이미지를 1행 8열로 붙여서 하나의 이미지로 만듦 (nrow = 한 행에 몇 개의 이미지를 배치할지)
x_grid = utils.make_grid(x_grid, nrow = grid_size, padding=2)

# 이미지 디스플레이 - 함수 호출
# 붙여진 이미지를 라벨과 함께 출력
show(x_grid, y_grid)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9929461..2.6500857].
# image indices:  [ 235 3980  905 2763 2895  144 4225 2797]

# %%
class BasicBlock(nn.Module):
    expansion=1
    def __init__(self, in_channels, out_channels, stride=1, drop_rate=0.1):
        super().__init__()
        self.drop_rate = drop_rate

        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels*BasicBlock.expansion, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels*BasicBlock.expansion)
        )
        self.shortcut = nn.Sequential()
        self.relu = nn.ReLU()

        # 이미지 크기가 다르거나, 채널 개수가 다르면
        if stride !=1 or in_channels != BasicBlock.expansion * out_channels:
            self.shortcut = nn.Sequential(
                # basic block에서는 downsample에서 kernel_size=1x1
                nn.Conv2d(in_channels, out_channels*BasicBlock.expansion, kernel_size=1, stride=stride),
                nn.BatchNorm2d(out_channels*BasicBlock.expansion)
            )

    def forward(self,x):
        if self.training and torch.rand(1).item() < self.drop_rate:
            return self.shortcut(x)  # 블록 꺼짐 → skip connection만
        
        x = self.residual_function(x) + self.shortcut(x)
        x = self.relu(x)
        return x

# %%
class BottleNeck(nn.Module):
    expansion=4
    def __init__(self, in_channels, out_channels, stride=1, drop_rate=0.1):
        super().__init__()
        self.drop_rate = drop_rate 

        self.residual_function = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
            nn.Conv2d(out_channels, out_channels*BottleNeck.expansion, kernel_size=1, stride=1, bias=False),
            nn.BatchNorm2d(out_channels*BottleNeck.expansion)
        )
        self.shortcut = nn.Sequential()
        self.relu = nn.ReLU()

        if stride !=1 or in_channels != out_channels*BottleNeck.expansion:
            self.shortcut = nn.Sequential(
                # downsample의 경우 대부분 kernel=1x1
                nn.Conv2d(in_channels, out_channels*BottleNeck.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels*BottleNeck.expansion)
            )

    def forward(self, x):
        # Stochastic Depth 적용
        if self.training and torch.rand(1).item() < self.drop_rate:
            return self.shortcut(x)  # 블록 꺼짐 → skip connection만
        
        x = self.residual_function(x) + self.shortcut(x)
        x = self.relu(x)
        return x

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_block, num_classes=10, init_weights=True): # init_weights=True(가중치 초기화)
        super().__init__()
        self.in_channels= 64 # 모두 처음 채널은 64로 시작한다.(ResNet에서 Conv1을 거치고 난 후의 채널 크기) 
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False), # 초반에 이미지 크기 확 줄이기(1/4)
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        )

        # block = Block의 개수
        self.conv2_x = self._make_layer(block, 64, num_block[0], 1) # 아마자 크기 유지
        self.conv3_x = self._make_layer(block, 128, num_block[1], 2) # 이미지 절반
        self.conv4_x = self._make_layer(block, 256, num_block[2], 2) # 이미지 절반
        self.conv5_x = self._make_layer(block, 512, num_block[3], 2) # 이미지 절반

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear(512*block.expansion, num_classes)

        if init_weights:
            self._initialize_weights()

    # 하나의 ResNet layer를 생성하는 함수 (여러 개의 residual block을 쌓음)
    # 파라미터 : residual block 종류, layer 채널 수, block 개수, stride
    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides=[stride] + [1]*(num_blocks-1) # stride의 길이 = num_blocks의 길이 
        layers=[] # 생성된 block들을 순서대로 당을 리스트 초기화
        for stride in strides:
            # residual block 생성 후 리스트에 추가
            layers.append(block(self.in_channels, out_channels, stride))
            # 다음 block을 위해 입력 채널 수 업데이트 
            self.in_channels = out_channels*block.expansion
        # 리스트에 담긴 block들을 순차적으로 연결하여 하나의 layer로 반환 
        return nn.Sequential(*layers)


    def forward(self,x):
        output = self.conv1(x)
        output = self.conv2_x(output)
        x=self.conv3_x(output)
        x=self.conv4_x(x)
        x=self.conv5_x(x)
        x=self.avg_pool(x)
        x=x.view(x.size(0),-1)
        x=self.fc(x)
        return x
    
    # ResNet 모델의 가중치 초기화
    def _initialize_weights(self):
        for m in self.modules(): # 모델 안에 포함된 모든 layer/block 순회
            if isinstance(m, nn.Conv2d): # m이 Conv2d인지 확인 
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None: # Conv layer에 bias가 있으면
                    nn.init.constant_(m.bias, 0) # bias=False로 초기화

            elif isinstance(m, nn.BatchNorm2d): # 현재 순회 중인 모듈 m이 BatchNorm2d인지 확인
                nn.init.constant_(m.weight,1) # BatchNorm의 scale=1
                nn.init.constant_(m.bias,0) # BatchNorm의 bias=0
                
            elif isinstance(m, nn.Linear): # 현재 순회 중인 모듈 m이 Linear layer인지 확인
                nn.init.normal_(m.weight, 0, 0.01) # Linear weight를 정규 분포(normal)로 초기화 시키기
                nn.init.constant_(m.bias, 0) # bias=0으로 초기화

# %%
def resnet18():
    return ResNet(BasicBlock, [2,2,2,2])

def resnet34():
    return ResNet(BasicBlock, [3,4,6,3])

def resnet50():
    return ResNet(BottleNeck, [3,4,6,3])

def resnet101():
    return ResNet(BottleNeck, [3,4,23,3])

def resnet152():
    return ResNet(BottleNeck, [3,8,36,3])

# %%
# 모델 생성 및 랜덤 입력 데이터로 실행 테스트 
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# ResNet50 모델 생성 후 지정한 장치로 이동
model = resnet50().to(device)

# 랜덤 입력 데이터 생성 (batch=3, channel=3, height=224, width=224)후 장치로 이동
# batch=3이면 3장의 이미지가 동시에 입력되는 것 
x=torch.randn(3,3,224,224).to(device) # 모델 구조 테스트용(모델이 오류가 없이 잘 돌아가는지 확인용)

# 모델에 입력 데이터를 넣어 forward 연산 수행
output = model(x) 
print(output.size())

# 예시 출력
# tensor([[ 0.32, -1.21,  0.54,  2.11, -0.33,  0.87, -0.12,  1.45, -0.98,  0.23],
#         [-0.11,  0.76,  1.23, -0.45,  0.88, -1.32,  0.54,  0.12, -0.67,  2.01],
#         [ 1.12, -0.34,  0.78,  0.45, -1.23,  0.91,  0.23, -0.87,  1.54, -0.12]])
#  ↑ batch 3개, 각각 10개 클래스에 대한 점수


# 가장 높은 점수의 클래스 선택
predicted = torch.argmax(output, dim=1)
print(predicted)  # tensor([3, 9, 8]) ← 각 배치의 예측 클래스 번호

# 모델 구조 요약 출력 
summary(model, (3,224,224), device = device.type)
# Out:
# cuda
# torch.Size([3, 10])
# tensor([4, 8, 5], device='cuda:0')
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 112, 112]           9,408
#        BatchNorm2d-2         [-1, 64, 112, 112]             128
#               ReLU-3         [-1, 64, 112, 112]               0
#          MaxPool2d-4           [-1, 64, 56, 56]               0
#             Conv2d-5           [-1, 64, 56, 56]           4,096
#        BatchNorm2d-6           [-1, 64, 56, 56]             128
#               ReLU-7           [-1, 64, 56, 56]               0
#             Conv2d-8           [-1, 64, 56, 56]          36,864
#        BatchNorm2d-9           [-1, 64, 56, 56]             128
#              ReLU-10           [-1, 64, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-12          [-1, 256, 56, 56]             512
#            Conv2d-13          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-14          [-1, 256, 56, 56]             512
#              ReLU-15          [-1, 256, 56, 56]               0
#        BottleNeck-16          [-1, 256, 56, 56]               0
#            Conv2d-17           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-18           [-1, 64, 56, 56]             128
#              ReLU-19           [-1, 64, 56, 56]               0
#            Conv2d-20           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-21           [-1, 64, 56, 56]             128
#              ReLU-22           [-1, 64, 56, 56]               0
#            Conv2d-23          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-24          [-1, 256, 56, 56]             512
#              ReLU-25          [-1, 256, 56, 56]               0
#        BottleNeck-26          [-1, 256, 56, 56]               0
#            Conv2d-27           [-1, 64, 56, 56]          16,384
#       BatchNorm2d-28           [-1, 64, 56, 56]             128
#              ReLU-29           [-1, 64, 56, 56]               0
#            Conv2d-30           [-1, 64, 56, 56]          36,864
#       BatchNorm2d-31           [-1, 64, 56, 56]             128
#              ReLU-32           [-1, 64, 56, 56]               0
#            Conv2d-33          [-1, 256, 56, 56]          16,384
#       BatchNorm2d-34          [-1, 256, 56, 56]             512
#              ReLU-35          [-1, 256, 56, 56]               0
#        BottleNeck-36          [-1, 256, 56, 56]               0
#            Conv2d-37          [-1, 128, 56, 56]          32,768
#       BatchNorm2d-38          [-1, 128, 56, 56]             256
#              ReLU-39          [-1, 128, 56, 56]               0
#            Conv2d-40          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-41          [-1, 128, 28, 28]             256
#              ReLU-42          [-1, 128, 28, 28]               0
#            Conv2d-43          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-44          [-1, 512, 28, 28]           1,024
#            Conv2d-45          [-1, 512, 28, 28]         131,072
#       BatchNorm2d-46          [-1, 512, 28, 28]           1,024
#              ReLU-47          [-1, 512, 28, 28]               0
#        BottleNeck-48          [-1, 512, 28, 28]               0
#            Conv2d-49          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-50          [-1, 128, 28, 28]             256
#              ReLU-51          [-1, 128, 28, 28]               0
#            Conv2d-52          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-53          [-1, 128, 28, 28]             256
#              ReLU-54          [-1, 128, 28, 28]               0
#            Conv2d-55          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-56          [-1, 512, 28, 28]           1,024
#              ReLU-57          [-1, 512, 28, 28]               0
#        BottleNeck-58          [-1, 512, 28, 28]               0
#            Conv2d-59          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-60          [-1, 128, 28, 28]             256
#              ReLU-61          [-1, 128, 28, 28]               0
#            Conv2d-62          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-63          [-1, 128, 28, 28]             256
#              ReLU-64          [-1, 128, 28, 28]               0
#            Conv2d-65          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-66          [-1, 512, 28, 28]           1,024
#              ReLU-67          [-1, 512, 28, 28]               0
#        BottleNeck-68          [-1, 512, 28, 28]               0
#            Conv2d-69          [-1, 128, 28, 28]          65,536
#       BatchNorm2d-70          [-1, 128, 28, 28]             256
#              ReLU-71          [-1, 128, 28, 28]               0
#            Conv2d-72          [-1, 128, 28, 28]         147,456
#       BatchNorm2d-73          [-1, 128, 28, 28]             256
#              ReLU-74          [-1, 128, 28, 28]               0
#            Conv2d-75          [-1, 512, 28, 28]          65,536
#       BatchNorm2d-76          [-1, 512, 28, 28]           1,024
#              ReLU-77          [-1, 512, 28, 28]               0
#        BottleNeck-78          [-1, 512, 28, 28]               0
#            Conv2d-79         [-1, 1024, 14, 14]         524,288
#       BatchNorm2d-80         [-1, 1024, 14, 14]           2,048
#        BottleNeck-81         [-1, 1024, 14, 14]               0
#            Conv2d-82          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-83          [-1, 256, 14, 14]             512
#              ReLU-84          [-1, 256, 14, 14]               0
#            Conv2d-85          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-86          [-1, 256, 14, 14]             512
#              ReLU-87          [-1, 256, 14, 14]               0
#            Conv2d-88         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-89         [-1, 1024, 14, 14]           2,048
#              ReLU-90         [-1, 1024, 14, 14]               0
#        BottleNeck-91         [-1, 1024, 14, 14]               0
#            Conv2d-92          [-1, 256, 14, 14]         262,144
#       BatchNorm2d-93          [-1, 256, 14, 14]             512
#              ReLU-94          [-1, 256, 14, 14]               0
#            Conv2d-95          [-1, 256, 14, 14]         589,824
#       BatchNorm2d-96          [-1, 256, 14, 14]             512
#              ReLU-97          [-1, 256, 14, 14]               0
#            Conv2d-98         [-1, 1024, 14, 14]         262,144
#       BatchNorm2d-99         [-1, 1024, 14, 14]           2,048
#             ReLU-100         [-1, 1024, 14, 14]               0
#       BottleNeck-101         [-1, 1024, 14, 14]               0
#           Conv2d-102          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-103          [-1, 256, 14, 14]             512
#             ReLU-104          [-1, 256, 14, 14]               0
#           Conv2d-105          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-106          [-1, 256, 14, 14]             512
#             ReLU-107          [-1, 256, 14, 14]               0
#           Conv2d-108         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-109         [-1, 1024, 14, 14]           2,048
#             ReLU-110         [-1, 1024, 14, 14]               0
#       BottleNeck-111         [-1, 1024, 14, 14]               0
#           Conv2d-112          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-113          [-1, 256, 14, 14]             512
#             ReLU-114          [-1, 256, 14, 14]               0
#           Conv2d-115          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-116          [-1, 256, 14, 14]             512
#             ReLU-117          [-1, 256, 14, 14]               0
#           Conv2d-118         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-119         [-1, 1024, 14, 14]           2,048
#             ReLU-120         [-1, 1024, 14, 14]               0
#       BottleNeck-121         [-1, 1024, 14, 14]               0
#           Conv2d-122          [-1, 256, 14, 14]         262,144
#      BatchNorm2d-123          [-1, 256, 14, 14]             512
#             ReLU-124          [-1, 256, 14, 14]               0
#           Conv2d-125          [-1, 256, 14, 14]         589,824
#      BatchNorm2d-126          [-1, 256, 14, 14]             512
#             ReLU-127          [-1, 256, 14, 14]               0
#           Conv2d-128         [-1, 1024, 14, 14]         262,144
#      BatchNorm2d-129         [-1, 1024, 14, 14]           2,048
#             ReLU-130         [-1, 1024, 14, 14]               0
#       BottleNeck-131         [-1, 1024, 14, 14]               0
#           Conv2d-132          [-1, 512, 14, 14]         524,288
#      BatchNorm2d-133          [-1, 512, 14, 14]           1,024
#             ReLU-134          [-1, 512, 14, 14]               0
#           Conv2d-135            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-136            [-1, 512, 7, 7]           1,024
#             ReLU-137            [-1, 512, 7, 7]               0
#           Conv2d-138           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-139           [-1, 2048, 7, 7]           4,096
#           Conv2d-140           [-1, 2048, 7, 7]       2,097,152
#      BatchNorm2d-141           [-1, 2048, 7, 7]           4,096
#             ReLU-142           [-1, 2048, 7, 7]               0
#       BottleNeck-143           [-1, 2048, 7, 7]               0
#           Conv2d-144            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-145            [-1, 512, 7, 7]           1,024
#             ReLU-146            [-1, 512, 7, 7]               0
#           Conv2d-147            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-148            [-1, 512, 7, 7]           1,024
#             ReLU-149            [-1, 512, 7, 7]               0
#           Conv2d-150           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-151           [-1, 2048, 7, 7]           4,096
#             ReLU-152           [-1, 2048, 7, 7]               0
#       BottleNeck-153           [-1, 2048, 7, 7]               0
#           Conv2d-154            [-1, 512, 7, 7]       1,048,576
#      BatchNorm2d-155            [-1, 512, 7, 7]           1,024
#             ReLU-156            [-1, 512, 7, 7]               0
#           Conv2d-157            [-1, 512, 7, 7]       2,359,296
#      BatchNorm2d-158            [-1, 512, 7, 7]           1,024
#             ReLU-159            [-1, 512, 7, 7]               0
#           Conv2d-160           [-1, 2048, 7, 7]       1,048,576
#      BatchNorm2d-161           [-1, 2048, 7, 7]           4,096
#             ReLU-162           [-1, 2048, 7, 7]               0
#       BottleNeck-163           [-1, 2048, 7, 7]               0
# AdaptiveAvgPool2d-164           [-1, 2048, 1, 1]               0
#           Linear-165                   [-1, 10]          20,490
# ================================================================
# Total params: 22,542,410
# Trainable params: 22,542,410
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 276.21
# Params size (MB): 85.99
# Estimated Total Size (MB): 362.78
# ----------------------------------------------------------------

# %%
# parameters
# reduction = 'sum' -> 배치 내 모든 샘플의 loss를 sum으로 계산
# reduction = 'mean' -> loss = (11+12+13)/3 
loss_func = nn.CrossEntropyLoss(reduction='sum', label_smoothing=0.1)

# Adam optimizer 설정
# model.parameters() -> 모델의 모든 학습 가능한 파라미터 전달
# lr = 0.001 -> 학습률
opt = optim.Adam(model.parameters(), lr=0.003)

# 변경
from torch.optim.lr_scheduler import CosineAnnealingLR
lr_scheduler = CosineAnnealingLR(opt, 
                                 T_max=350, # 총 epoch
                                 eta_min=0) # 최소 학습률


# optimizer의 현재 학습률을 반환하는 함수 
def get_lr(opt):
    # Pytorch Optimizer는 param_groups라는 리스트로 파라미터 그룹과 학습률 관리
    # 보통 하나의 그룹만 쓰지만, 여러 그룹 가능 
    for param_group in opt.param_groups:
        # 첫 번째 param_group의 'lr'값을 반환
        return param_group['lr']
    
# opt.param_groups[0] 출력 예시
# {
#     'lr': 0.001,          # 학습률
#     'betas': (0.9, 0.999) # Adam 관련 파라미터
#     'eps': 1e-08,
#     'weight_decay': 0,
#     'params': [...]       # 모델의 가중치들
# }

# %%
# metric & loss per mini-batch
# 한 배치에서 정확히 맞춘 샘플 수를 계산하는 함수 
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True) # 각 샘플에서 가장 높은 점수의 클래스 번호 선택 [3,1]
    corrects = pred.eq(target.view_as(pred)).sum().item() # target shape을 pred와 같은 shape으로 변환
    return corrects

# 한 배치에 대해 손실(loss)과 정확도(metric) 계산
# optimizer가 주어지면 역전파와 파라미터 업데이트까지 수행하는 함수
def loss_batch(loss_func, output, target, opt=None):
    loss= loss_func(output, target) # 손실 게산
    metric_b = metric_batch(output, target) # 정확도 계산

    if opt is not None: # optimizer가 있으면(=학습중이면)
        opt.zero_grad() # 이전 기울기 초기화
        loss.backward() # 역전파
        opt.step() # 가중치 업데이트

    return loss.item(), metric_b

# fucntion to calculate loss and metric per epoch(전체 epoch loss 계산)
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric=0.0
    len_data=len(dataset_dl.dataset) # 전체 데이터 수

    for xb, yb in dataset_dl: # 미니배치마다 반복
        xb=xb.to(device) # 입력 데이터 gpu로
        yb=yb.to(device) # 정답 레이블 gpu로
        output=model(xb) # forward 연산

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)
        running_loss +=loss_b # 배치 loss 누적

        if metric_b is not None:
            running_metric +=metric_b # 배치 정확도 누적

        if sanity_check is True: # sanity_check면 1배치만 실행(학습 전에 코드가 잘 돌아가는지 확인하는 용도)
            break

    loss = running_loss/len_data # 전체 평균 loss
    metric = running_metric/len_data # 전체 평균 정확도

    return loss, metric # loss, 맞춘 샘플 수 반환

# %%
# DataLoader에서 배치 하나 꺼내기
xb, yb = next(iter(train_dl))

print("xb type:", type(xb))
print("xb shape:", xb.shape)  # [32, 3, 224, 224]
print("yb shape:", yb.shape)  # [32]
print("yb:", yb)              # 라벨 32개

# 첫 번째 이미지 시각화
show(xb[0], yb[0])

# 배치에서 8장만 그리드로 출력
x_grid = utils.make_grid(xb[:8], nrow=8, padding=2)
show(x_grid, yb[:8].tolist())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8740476..2.6500857].
# xb type: <class 'torch.Tensor'>
# xb shape: torch.Size([32, 3, 224, 224])
# yb shape: torch.Size([32])
# yb: tensor([0, 7, 0, 9, 2, 1, 9, 1, 2, 6, 1, 0, 6, 6, 4, 2, 3, 3, 4, 9, 2, 3, 4, 2,
#         3, 9, 4, 0, 8, 9, 9, 9])
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9929461..2.6500857].

# %%
# Model Train
def train_val(model, params):
    num_epochs = params['num_epochs'] # 총 학습 횟수
    loss_func = params['loss_func'] # loss 함수
    opt = params['optimizer'] # optimizer
    train_dl = params['train_dl'] # 학습 데이터로더
    val_dl = params['val_dl'] # 검증 데이터로더
    sanity_check = params['sanity_check'] # 디버깅용 샘플만 돌릴지 여부
    lr_scheduler = params['lr_scheduler'] # 학습률 스케줄러
    path2weights = params['path2weights'] # 학습 완료 모델 저장 경로

    # 학습 및 검증 loss와 metric을 기록할 딕셔너리 초기화
    loss_history = {'train':[], 'val':[]}
    metric_history = {'train':[], 'val':[]}

    # validation loss 최소값 초기화(비교용)
    best_loss = float('inf') # 초기에는 무한대로 설정하여 첫 epoch에서 갱신 가능

    # 학습 시작 시간 기록
    start_time = time.time()

    for epoch in range(num_epochs): # 현재 epoch 반복
        current_lr = get_lr(opt)
        print("Epoch {}/{}, current lr={}".format(epoch, num_epochs-1, current_lr))

        model.train() # 학습 모드 설정(Dropout, BatchNorm 활성화)
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss) # 학습 데이터로 loss, metric 계산
        metric_history['train'].append(train_metric) # 학습 loss와 metric 기록

        model.eval() # 모델을 평가모드로 설정(Dropout, BatchNorm 비활성화)
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)

        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        # best_loss 갱신
        if val_loss < best_loss:
            best_loss = val_loss
            torch.save(model.state_dict(), path2weights)
            print("Get Best val_loss")

        lr_scheduler.step() # val_loss 필요 없음
        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time:%.4fmin' 
              %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    return model, loss_history, metric_history

# %%
# define the training parameters
params_train = {
    'num_epochs':350,
    'optimizer':opt,
    'loss_func': loss_func,
    'train_dl': train_dl,
    'val_dl': val_dl,
    'sanity_check': False,
    'lr_scheduler': lr_scheduler,
    'path2weights': './models/weights.pt',
}

# create the directory that stores weights.pt
# 지정한 경로가 폴더에 없으면 새로 생성하는 함수 
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print('Error')

createFolder('./models')

model, loss_hist, metric_hist = train_val(model, params_train) # 학습 시작
# Out:
# Epoch 0/349, current lr=0.003
# Get Best val_loss
# train loss: 2.346934, val loss: 2.133945, accuracy: 24.12, time:0.8672min
# ----------
# Epoch 1/349, current lr=0.0029999395742563066
# train loss: 1.966641, val loss: 2.587156, accuracy: 22.41, time:1.7328min
# ----------
# Epoch 2/349, current lr=0.0029997583018935873
# train loss: 1.923566, val loss: 2.221068, accuracy: 25.82, time:2.6200min
# ----------
# Epoch 3/349, current lr=0.002999456197516532
# Get Best val_loss
# train loss: 1.863945, val loss: 2.011344, accuracy: 29.61, time:3.5123min
# ----------
# Epoch 4/349, current lr=0.0029990332854649823
# Get Best val_loss
# train loss: 1.817225, val loss: 1.905013, accuracy: 33.67, time:4.4032min
# ----------
# Epoch 5/349, current lr=0.0029984895998119722
# train loss: 1.804120, val loss: 1.979685, accuracy: 32.07, time:5.2985min
# ----------
# Epoch 6/349, current lr=0.0029978251843609817
# train loss: 1.797355, val loss: 2.017986, accuracy: 32.77, time:6.1916min
# ----------
# Epoch 7/349, current lr=0.0029970400926424075
# Get Best val_loss
# train loss: 1.803454, val loss: 1.859199, accuracy: 33.10, time:7.0960min
# ----------
# Epoch 8/349, current lr=0.0029961343879092513
# train loss: 1.751965, val loss: 1.863857, accuracy: 36.19, time:8.0004min
# ----------
# Epoch 9/349, current lr=0.0029951081431320217
# Get Best val_loss
# train loss: 1.700960, val loss: 1.765193, accuracy: 38.96, time:8.9012min
# ----------
# Epoch 10/349, current lr=0.002993961440992859
# train loss: 1.694894, val loss: 2.656009, accuracy: 35.74, time:9.7912min
# ----------
# Epoch 11/349, current lr=0.002992694373878867
# train loss: 1.642699, val loss: 1.786998, accuracy: 42.50, time:10.7045min
# ----------
# Epoch 12/349, current lr=0.0029913070438746772
# Get Best val_loss
# train loss: 1.621491, val loss: 1.724926, accuracy: 40.44, time:11.6269min
# ----------
# Epoch 13/349, current lr=0.0029897995627542195
# Get Best val_loss
# train loss: 1.592133, val loss: 1.662803, accuracy: 45.31, time:12.5574min
# ----------
# Epoch 14/349, current lr=0.0029881720519717167
# train loss: 1.523904, val loss: 1.670322, accuracy: 46.67, time:13.4816min
# ----------
# Epoch 15/349, current lr=0.002986424642651902
# train loss: 1.496505, val loss: 1.883022, accuracy: 44.35, time:14.3972min
# ----------
# Epoch 16/349, current lr=0.0029845574755794518
# train loss: 1.433956, val loss: 1.700198, accuracy: 45.44, time:15.3118min
# ----------
# Epoch 17/349, current lr=0.002982570701187646
# Get Best val_loss
# train loss: 1.440936, val loss: 1.596344, accuracy: 53.30, time:16.2226min
# ----------
# Epoch 18/349, current lr=0.0029804644795462434
# Get Best val_loss
# train loss: 1.380701, val loss: 1.431182, accuracy: 57.57, time:17.1286min
# ----------
# Epoch 19/349, current lr=0.00297823898034859
# train loss: 1.362514, val loss: 1.464589, accuracy: 57.03, time:18.0370min
# ----------
# Epoch 20/349, current lr=0.002975894382897944
# train loss: 1.312819, val loss: 1.486249, accuracy: 55.43, time:18.9472min
# ----------
# Epoch 21/349, current lr=0.0029734308760930328
# train loss: 1.321558, val loss: 1.505469, accuracy: 55.19, time:19.8606min
# ----------
# Epoch 22/349, current lr=0.00297084865841283
# train loss: 1.261762, val loss: 1.450654, accuracy: 57.84, time:20.7702min
# ----------
# Epoch 23/349, current lr=0.002968147937900567
# Get Best val_loss
# train loss: 1.287852, val loss: 1.373946, accuracy: 59.42, time:21.6809min
# ----------
# Epoch 24/349, current lr=0.002965328932146971
# train loss: 1.201316, val loss: 2.919398, accuracy: 40.76, time:22.5999min
# ----------
# Epoch 25/349, current lr=0.002962391868272735
# Get Best val_loss
# train loss: 1.179114, val loss: 1.320693, accuracy: 64.30, time:23.5117min
# ----------
# Epoch 26/349, current lr=0.002959336982910217
# train loss: 1.145998, val loss: 1.430784, accuracy: 59.79, time:24.4347min
# ----------
# Epoch 27/349, current lr=0.0029561645221843767
# train loss: 1.125426, val loss: 1.441221, accuracy: 59.88, time:25.3576min
# ----------
# Epoch 28/349, current lr=0.002952874741692946
# train loss: 1.105967, val loss: 1.478435, accuracy: 57.48, time:26.2875min
# ----------
# Epoch 29/349, current lr=0.0029494679064858355
# train loss: 1.079071, val loss: 1.514340, accuracy: 57.49, time:27.2047min
# ----------
# Epoch 30/349, current lr=0.002945944291043779
# Get Best val_loss
# train loss: 1.045774, val loss: 1.303683, accuracy: 65.33, time:28.1100min
# ----------
# Epoch 31/349, current lr=0.002942304179256223
# Get Best val_loss
# train loss: 1.028625, val loss: 1.299276, accuracy: 66.19, time:29.0194min
# ----------
# Epoch 32/349, current lr=0.002938547864398448
# train loss: 1.001834, val loss: 1.453226, accuracy: 60.54, time:29.9267min
# ----------
# Epoch 33/349, current lr=0.002934675649107947
# train loss: 0.978883, val loss: 1.359784, accuracy: 64.21, time:30.8393min
# ----------
# Epoch 34/349, current lr=0.0029306878453600376
# train loss: 0.999645, val loss: 1.317858, accuracy: 64.20, time:31.7601min
# ----------
# Epoch 35/349, current lr=0.00292658477444273
# train loss: 0.936506, val loss: 1.531074, accuracy: 60.11, time:32.6589min
# ----------
# Epoch 36/349, current lr=0.0029223667669308387
# train loss: 0.913049, val loss: 1.433053, accuracy: 62.01, time:33.5630min
# ----------
# Epoch 37/349, current lr=0.0029180341626593525
# train loss: 0.884180, val loss: 1.418316, accuracy: 62.76, time:34.4739min
# ----------
# Epoch 38/349, current lr=0.002913587310696052
# train loss: 0.844951, val loss: 1.320527, accuracy: 67.05, time:35.3551min
# ----------
# Epoch 39/349, current lr=0.002909026569313385
# train loss: 0.808860, val loss: 1.336827, accuracy: 66.16, time:36.2546min
# ----------
# Epoch 40/349, current lr=0.002904352305959605
# train loss: 0.806392, val loss: 1.478429, accuracy: 62.11, time:37.1603min
# ----------
# Epoch 41/349, current lr=0.0028995648972291654
# train loss: 0.792469, val loss: 1.498428, accuracy: 62.51, time:38.0557min
# ----------
# Epoch 42/349, current lr=0.0028946647288323763
# train loss: 0.764364, val loss: 1.326945, accuracy: 67.03, time:38.9613min
# ----------
# Epoch 43/349, current lr=0.0028896521955643303
# train loss: 0.741893, val loss: 1.404164, accuracy: 62.81, time:39.8470min
# ----------
# Epoch 44/349, current lr=0.002884527701273095
# train loss: 0.884050, val loss: 1.325107, accuracy: 66.41, time:40.7434min
# ----------
# Epoch 45/349, current lr=0.002879291658827175
# train loss: 0.864774, val loss: 1.670253, accuracy: 63.18, time:41.6277min
# ----------
# Epoch 46/349, current lr=0.002873944490082249
# train loss: 0.713393, val loss: 1.696076, accuracy: 61.91, time:42.5135min
# ----------
# Epoch 47/349, current lr=0.002868486625847181
# train loss: 0.776893, val loss: 2.386373, accuracy: 59.41, time:43.3905min
# ----------
# Epoch 48/349, current lr=0.002862918505849311
# Get Best val_loss
# train loss: 0.691358, val loss: 1.288758, accuracy: 68.39, time:44.2750min
# ----------
# Epoch 49/349, current lr=0.002857240578699029
# train loss: 0.725496, val loss: 1.341184, accuracy: 67.22, time:45.1498min
# ----------
# Epoch 50/349, current lr=0.002851453301853628
# train loss: 0.676109, val loss: 1.361390, accuracy: 65.85, time:46.0180min
# ----------
# Epoch 51/349, current lr=0.0028455571415804525
# train loss: 0.665261, val loss: 1.386738, accuracy: 65.44, time:46.8763min
# ----------
# Epoch 52/349, current lr=0.002839552572919328
# train loss: 0.645727, val loss: 1.356210, accuracy: 65.91, time:47.7434min
# ----------
# Epoch 53/349, current lr=0.0028334400796442894
# train loss: 0.629189, val loss: 1.319776, accuracy: 66.49, time:48.5983min
# ----------
# Epoch 54/349, current lr=0.002827220154224607
# train loss: 0.612681, val loss: 1.328633, accuracy: 66.47, time:49.4671min
# ----------
# Epoch 55/349, current lr=0.0028208932977851066
# train loss: 0.610803, val loss: 1.537629, accuracy: 61.82, time:50.3160min
# ----------
# Epoch 56/349, current lr=0.002814460020065795
# Get Best val_loss
# train loss: 0.609472, val loss: 1.252424, accuracy: 69.25, time:51.1772min
# ----------
# Epoch 57/349, current lr=0.0028079208393807934
# train loss: 0.595911, val loss: 1.258847, accuracy: 68.85, time:52.0279min
# ----------
# Epoch 58/349, current lr=0.002801276282576576
# train loss: 0.589546, val loss: 1.551634, accuracy: 64.21, time:52.8706min
# ----------
# Epoch 59/349, current lr=0.002794526884989525
# train loss: 0.691186, val loss: 1.463071, accuracy: 64.20, time:53.7283min
# ----------
# Epoch 60/349, current lr=0.002787673190402799
# train loss: 0.648596, val loss: 1.341988, accuracy: 66.71, time:54.5576min
# ----------
# Epoch 61/349, current lr=0.0027807157510025206
# train loss: 0.663034, val loss: 1.291549, accuracy: 67.92, time:55.4014min
# ----------
# Epoch 62/349, current lr=0.0027736551273332905
# train loss: 0.589327, val loss: 1.284887, accuracy: 68.75, time:56.2374min
# ----------
# Epoch 63/349, current lr=0.0027664918882530226
# train loss: 0.592625, val loss: 1.282889, accuracy: 67.05, time:57.0900min
# ----------
# Epoch 64/349, current lr=0.0027592266108871157
# train loss: 0.578273, val loss: 1.301841, accuracy: 66.90, time:57.9388min
# ----------
# Epoch 65/349, current lr=0.002751859880581954
# train loss: 0.649803, val loss: 1.517377, accuracy: 62.16, time:58.7958min
# ----------
# Epoch 66/349, current lr=0.0027443922908577468
# train loss: 0.647747, val loss: 1.344676, accuracy: 65.50, time:59.6480min
# ----------
# Epoch 67/349, current lr=0.002736824443360711
# train loss: 0.612764, val loss: 1.260072, accuracy: 68.61, time:60.5083min
# ----------
# Epoch 68/349, current lr=0.002729156947814598
# train loss: 0.583223, val loss: 1.305316, accuracy: 66.22, time:61.3574min
# ----------
# Epoch 69/349, current lr=0.0027213904219715677
# train loss: 0.589440, val loss: 1.279887, accuracy: 67.70, time:62.1930min
# ----------
# Epoch 70/349, current lr=0.0027135254915624215
# Get Best val_loss
# train loss: 0.567031, val loss: 1.242905, accuracy: 68.69, time:63.0456min
# ----------
# Epoch 71/349, current lr=0.002705562790246183
# train loss: 0.566996, val loss: 1.255560, accuracy: 68.54, time:63.8997min
# ----------
# Epoch 72/349, current lr=0.002697502959559052
# Get Best val_loss
# train loss: 0.573103, val loss: 1.207645, accuracy: 70.21, time:64.7624min
# ----------
# Epoch 73/349, current lr=0.0026893466488627127
# train loss: 0.562385, val loss: 1.312816, accuracy: 65.83, time:65.6400min
# ----------
# Epoch 74/349, current lr=0.0026810945152920176
# train loss: 0.574456, val loss: 1.264810, accuracy: 67.44, time:66.4997min
# ----------
# Epoch 75/349, current lr=0.0026727472237020444
# train loss: 0.639034, val loss: 1.373428, accuracy: 64.86, time:67.3561min
# ----------
# Epoch 76/349, current lr=0.0026643054466145293
# train loss: 0.594830, val loss: 1.247121, accuracy: 68.71, time:68.2248min
# ----------
# Epoch 77/349, current lr=0.0026557698641636834
# train loss: 0.621453, val loss: 1.329293, accuracy: 66.07, time:69.1003min
# ----------
# Epoch 78/349, current lr=0.002647141164041397
# train loss: 0.586869, val loss: 1.265289, accuracy: 67.53, time:69.9665min
# ----------
# Epoch 79/349, current lr=0.0026384200414418324
# train loss: 0.573119, val loss: 1.322350, accuracy: 67.84, time:70.8400min
# ----------
# Epoch 80/349, current lr=0.002629607199005416
# train loss: 0.564385, val loss: 1.233576, accuracy: 68.65, time:71.7347min
# ----------
# Epoch 81/349, current lr=0.002620703346762224
# train loss: 0.623883, val loss: 1.296933, accuracy: 67.36, time:72.6244min
# ----------
# Epoch 82/349, current lr=0.0026117092020747816
# train loss: 0.571083, val loss: 1.238838, accuracy: 68.94, time:73.5051min
# ----------
# Epoch 83/349, current lr=0.0026026254895802643
# train loss: 0.554650, val loss: 1.243344, accuracy: 68.85, time:74.4062min
# ----------
# Epoch 84/349, current lr=0.0025934529411321167
# train loss: 0.547912, val loss: 1.224140, accuracy: 69.61, time:75.2976min
# ----------
# Epoch 85/349, current lr=0.0025841922957410865
# train loss: 0.546031, val loss: 1.245084, accuracy: 68.97, time:76.1976min
# ----------
# Epoch 86/349, current lr=0.002574844299515688
# train loss: 0.612671, val loss: 1.633869, accuracy: 65.29, time:77.0995min
# ----------
# Epoch 87/349, current lr=0.0025654097056020853
# train loss: 0.553178, val loss: 1.282390, accuracy: 67.04, time:78.0028min
# ----------
# Epoch 88/349, current lr=0.002555889274123417
# train loss: 0.549263, val loss: 1.271502, accuracy: 67.97, time:78.8953min
# ----------
# Epoch 89/349, current lr=0.002546283772118553
# train loss: 0.541376, val loss: 1.278238, accuracy: 67.60, time:79.7963min
# ----------
# Epoch 90/349, current lr=0.0025365939734802966
# train loss: 0.531514, val loss: 1.211210, accuracy: 69.47, time:80.7030min
# ----------
# Epoch 91/349, current lr=0.0025268206588930325
# train loss: 0.537007, val loss: 1.231301, accuracy: 68.67, time:81.6054min
# ----------
# Epoch 92/349, current lr=0.002516964615769831
# train loss: 0.536441, val loss: 1.252838, accuracy: 68.62, time:82.5006min
# ----------
# Epoch 93/349, current lr=0.002507026638189006
# train loss: 0.533622, val loss: 1.312992, accuracy: 66.14, time:83.4176min
# ----------
# Epoch 94/349, current lr=0.0024970075268301384
# train loss: 0.547427, val loss: 1.333526, accuracy: 64.14, time:84.3134min
# ----------
# Epoch 95/349, current lr=0.002486908088909569
# train loss: 0.547716, val loss: 1.266296, accuracy: 67.97, time:85.2265min
# ----------
# Epoch 96/349, current lr=0.0024767291381153603
# train loss: 0.542140, val loss: 1.241226, accuracy: 68.76, time:86.1442min
# ----------
# Epoch 97/349, current lr=0.002466471494541742
# train loss: 0.558536, val loss: 1.315214, accuracy: 65.21, time:87.0340min
# ----------
# Epoch 98/349, current lr=0.002456135984623035
# train loss: 0.587344, val loss: 1.414836, accuracy: 62.35, time:87.9427min
# ----------
# Epoch 99/349, current lr=0.002445723441067071
# train loss: 0.587604, val loss: 1.294802, accuracy: 67.06, time:88.8688min
# ----------
# Epoch 100/349, current lr=0.002435234702788101
# train loss: 0.553437, val loss: 1.240604, accuracy: 69.09, time:89.7793min
# ----------
# Epoch 101/349, current lr=0.0024246706148392055
# train loss: 0.545530, val loss: 1.270099, accuracy: 66.15, time:90.6979min
# ----------
# Epoch 102/349, current lr=0.0024140320283442132
# train loss: 0.530701, val loss: 1.239672, accuracy: 68.19, time:91.6146min
# ----------
# Epoch 103/349, current lr=0.002403319800429124
# train loss: 0.535253, val loss: 1.238392, accuracy: 68.79, time:92.5284min
# ----------
# Epoch 104/349, current lr=0.0023925347941530562
# train loss: 0.536938, val loss: 1.243554, accuracy: 67.30, time:93.4448min
# ----------
# Epoch 105/349, current lr=0.0023816778784387102
# train loss: 0.532773, val loss: 1.274285, accuracy: 66.60, time:94.3731min
# ----------
# Epoch 106/349, current lr=0.0023707499280023604
# train loss: 0.531244, val loss: 1.261648, accuracy: 67.47, time:95.2941min
# ----------
# Epoch 107/349, current lr=0.002359751823283384
# train loss: 0.528892, val loss: 1.288926, accuracy: 66.90, time:96.2118min
# ----------
# Epoch 108/349, current lr=0.002348684450373322
# train loss: 0.553388, val loss: 2.092281, accuracy: 55.23, time:97.1279min
# ----------
# Epoch 109/349, current lr=0.0023375487009444943
# train loss: 0.557892, val loss: 1.273337, accuracy: 67.84, time:98.0334min
# ----------
# Epoch 110/349, current lr=0.0023263454721781543
# train loss: 0.532295, val loss: 1.310865, accuracy: 67.30, time:98.9471min
# ----------
# Epoch 111/349, current lr=0.002315075666692209
# train loss: 0.528202, val loss: 1.272773, accuracy: 67.10, time:99.8725min
# ----------
# Epoch 112/349, current lr=0.0023037401924684954
# train loss: 0.535654, val loss: 1.315852, accuracy: 65.25, time:100.7804min
# ----------
# Epoch 113/349, current lr=0.0022923399627796273
# train loss: 0.523895, val loss: 1.286783, accuracy: 66.44, time:101.6973min
# ----------
# Epoch 114/349, current lr=0.0022808758961154136
# train loss: 0.530050, val loss: 1.273691, accuracy: 67.39, time:102.6171min
# ----------
# Epoch 115/349, current lr=0.00226934891610886
# train loss: 0.536325, val loss: 1.313304, accuracy: 65.95, time:103.5291min
# ----------
# Epoch 116/349, current lr=0.0022577599514617516
# train loss: 0.535563, val loss: 1.264570, accuracy: 67.27, time:104.4442min
# ----------
# Epoch 117/349, current lr=0.0022461099358698335
# train loss: 0.527099, val loss: 1.270411, accuracy: 67.95, time:105.3683min
# ----------
# Epoch 118/349, current lr=0.0022343998079475793
# train loss: 0.527963, val loss: 1.263786, accuracy: 67.34, time:106.2912min
# ----------
# Epoch 119/349, current lr=0.0022226305111525736
# train loss: 0.527685, val loss: 1.250258, accuracy: 68.14, time:107.2099min
# ----------
# Epoch 120/349, current lr=0.002210802993709499
# train loss: 0.519580, val loss: 1.251156, accuracy: 67.97, time:108.1187min
# ----------
# Epoch 121/349, current lr=0.002198918208533738
# train loss: 0.530699, val loss: 1.252329, accuracy: 68.14, time:109.0335min
# ----------
# Epoch 122/349, current lr=0.002186977113154602
# train loss: 0.566761, val loss: 1.331768, accuracy: 65.36, time:109.9412min
# ----------
# Epoch 123/349, current lr=0.0021749806696381825
# train loss: 0.538171, val loss: 1.285937, accuracy: 66.47, time:110.8527min
# ----------
# Epoch 124/349, current lr=0.0021629298445098415
# train loss: 0.564253, val loss: 1.316720, accuracy: 66.81, time:111.7523min
# ----------
# Epoch 125/349, current lr=0.002150825608676338
# train loss: 0.528775, val loss: 1.235139, accuracy: 67.71, time:112.6610min
# ----------
# Epoch 126/349, current lr=0.00213866893734761
# train loss: 0.526383, val loss: 1.269693, accuracy: 68.26, time:113.5674min
# ----------
# Epoch 127/349, current lr=0.0021264608099581975
# train loss: 0.525403, val loss: 1.256323, accuracy: 67.67, time:114.4697min
# ----------
# Epoch 128/349, current lr=0.002114202210088337
# train loss: 0.521208, val loss: 1.254828, accuracy: 68.05, time:115.3675min
# ----------
# Epoch 129/349, current lr=0.002101894125384712
# train loss: 0.531265, val loss: 1.311262, accuracy: 65.18, time:116.2647min
# ----------
# Epoch 130/349, current lr=0.0020895375474808864
# train loss: 0.524169, val loss: 1.253050, accuracy: 67.62, time:117.1660min
# ----------
# Epoch 131/349, current lr=0.002077133471917405
# train loss: 0.522681, val loss: 1.268506, accuracy: 67.85, time:118.0698min
# ----------
# Epoch 132/349, current lr=0.002064682898061589
# train loss: 0.519618, val loss: 1.244788, accuracy: 68.51, time:118.9632min
# ----------
# Epoch 133/349, current lr=0.002052186829027018
# train loss: 0.520704, val loss: 1.265078, accuracy: 67.40, time:119.8404min
# ----------
# Epoch 134/349, current lr=0.002039646271592712
# train loss: 0.520013, val loss: 1.254304, accuracy: 67.44, time:120.7023min
# ----------
# Epoch 135/349, current lr=0.0020270622361220152
# train loss: 0.515778, val loss: 1.243245, accuracy: 68.75, time:121.5768min
# ----------
# Epoch 136/349, current lr=0.0020144357364811983
# train loss: 0.514181, val loss: 1.265130, accuracy: 68.00, time:122.4535min
# ----------
# Epoch 137/349, current lr=0.002001767789957769
# train loss: 0.515451, val loss: 1.255882, accuracy: 67.40, time:123.3330min
# ----------
# Epoch 138/349, current lr=0.001989059417178514
# train loss: 0.523441, val loss: 1.268278, accuracy: 68.31, time:124.2021min
# ----------
# Epoch 139/349, current lr=0.001976311642027268
# train loss: 0.523026, val loss: 1.300924, accuracy: 66.27, time:125.0834min
# ----------
# Epoch 140/349, current lr=0.001963525491562422
# train loss: 0.527059, val loss: 1.268868, accuracy: 67.15, time:125.9356min
# ----------
# Epoch 141/349, current lr=0.0019507019959341793
# train loss: 0.524315, val loss: 1.319812, accuracy: 64.92, time:126.8042min
# ----------
# Epoch 142/349, current lr=0.0019378421883015512
# train loss: 0.635025, val loss: 1.549298, accuracy: 59.95, time:127.6709min
# ----------
# Epoch 143/349, current lr=0.0019249471047491254
# train loss: 0.634668, val loss: 1.475887, accuracy: 60.16, time:128.5326min
# ----------
# Epoch 144/349, current lr=0.0019120177842035866
# train loss: 0.553002, val loss: 1.354573, accuracy: 63.66, time:129.3850min
# ----------
# Epoch 145/349, current lr=0.0018990552683500138
# train loss: 0.522350, val loss: 1.258465, accuracy: 68.83, time:130.2477min
# ----------
# Epoch 146/349, current lr=0.0018860606015479548
# train loss: 0.516437, val loss: 1.232656, accuracy: 68.55, time:131.1144min
# ----------
# Epoch 147/349, current lr=0.0018730348307472832
# train loss: 0.521869, val loss: 1.242908, accuracy: 68.47, time:131.9715min
# ----------
# Epoch 148/349, current lr=0.0018599790054038502
# train loss: 0.516817, val loss: 1.411692, accuracy: 65.49, time:132.8328min
# ----------
# Epoch 149/349, current lr=0.0018468941773949297
# train loss: 0.526346, val loss: 1.269285, accuracy: 67.53, time:133.6822min
# ----------
# Epoch 150/349, current lr=0.0018337814009344727
# train loss: 0.518179, val loss: 1.327934, accuracy: 64.19, time:134.5283min
# ----------
# Epoch 151/349, current lr=0.001820641732488173
# train loss: 0.529030, val loss: 1.291752, accuracy: 67.50, time:135.3671min
# ----------
# Epoch 152/349, current lr=0.001807476230688347
# train loss: 0.518116, val loss: 1.283248, accuracy: 67.26, time:136.2036min
# ----------
# Epoch 153/349, current lr=0.001794285956248644
# train loss: 0.524348, val loss: 1.283211, accuracy: 67.31, time:137.0383min
# ----------
# Epoch 154/349, current lr=0.0017810719718785884
# train loss: 0.515146, val loss: 1.243784, accuracy: 68.83, time:137.8727min
# ----------
# Epoch 155/349, current lr=0.001767835342197956
# train loss: 0.514580, val loss: 1.260374, accuracy: 67.94, time:138.7122min
# ----------
# Epoch 156/349, current lr=0.0017545771336510043
# train loss: 0.512988, val loss: 1.271229, accuracy: 67.01, time:139.5585min
# ----------
# Epoch 157/349, current lr=0.0017412984144205492
# train loss: 0.511628, val loss: 1.242540, accuracy: 68.77, time:140.4100min
# ----------
# Epoch 158/349, current lr=0.0017280002543419016
# train loss: 0.514263, val loss: 1.229846, accuracy: 68.46, time:141.2613min
# ----------
# Epoch 159/349, current lr=0.0017146837248166805
# train loss: 0.533931, val loss: 1.290123, accuracy: 66.61, time:142.1277min
# ----------
# Epoch 160/349, current lr=0.0017013498987264845
# train loss: 0.514841, val loss: 1.310368, accuracy: 65.69, time:142.9853min
# ----------
# Epoch 161/349, current lr=0.0016879998503464577
# train loss: 0.513288, val loss: 1.258318, accuracy: 68.42, time:143.8588min
# ----------
# Epoch 162/349, current lr=0.0016746346552587357
# train loss: 0.511848, val loss: 1.219802, accuracy: 69.54, time:144.7366min
# ----------
# Epoch 163/349, current lr=0.0016612553902657888
# train loss: 0.512656, val loss: 1.232169, accuracy: 69.40, time:145.5958min
# ----------
# Epoch 164/349, current lr=0.0016478631333036666
# train loss: 0.516459, val loss: 1.284168, accuracy: 67.66, time:146.4685min
# ----------
# Epoch 165/349, current lr=0.0016344589633551518
# train loss: 0.510212, val loss: 1.249905, accuracy: 68.33, time:147.3476min
# ----------
# Epoch 166/349, current lr=0.001621043960362827
# train loss: 0.514069, val loss: 1.257099, accuracy: 68.69, time:148.2334min
# ----------
# Epoch 167/349, current lr=0.0016076192051420698
# train loss: 0.513687, val loss: 1.238665, accuracy: 68.65, time:149.1302min
# ----------
# Epoch 168/349, current lr=0.0015941857792939709
# train loss: 0.510298, val loss: 1.232363, accuracy: 68.77, time:150.0232min
# ----------
# Epoch 169/349, current lr=0.0015807447651181934
# train loss: 0.512620, val loss: 1.252091, accuracy: 68.49, time:150.9079min
# ----------
# Epoch 170/349, current lr=0.0015672972455257736
# train loss: 0.510794, val loss: 1.251642, accuracy: 68.60, time:151.7989min
# ----------
# Epoch 171/349, current lr=0.0015538443039518743
# train loss: 0.544754, val loss: 1.287251, accuracy: 67.94, time:152.6870min
# ----------
# Epoch 172/349, current lr=0.0015403870242684957
# train loss: 0.520455, val loss: 1.246010, accuracy: 67.26, time:153.5700min
# ----------
# Epoch 173/349, current lr=0.001526926490697147
# train loss: 0.516764, val loss: 1.269492, accuracy: 68.05, time:154.4526min
# ----------
# Epoch 174/349, current lr=0.001513463787721498
# train loss: 0.514571, val loss: 1.254019, accuracy: 67.89, time:155.3556min
# ----------
# Epoch 175/349, current lr=0.0015000000000000013
# train loss: 0.520306, val loss: 1.266911, accuracy: 66.97, time:156.2375min
# ----------
# Epoch 176/349, current lr=0.0014865362122785046
# train loss: 0.512523, val loss: 1.255569, accuracy: 67.65, time:157.1451min
# ----------
# Epoch 177/349, current lr=0.0014730735093028552
# train loss: 0.512567, val loss: 1.267084, accuracy: 67.71, time:158.0388min
# ----------
# Epoch 178/349, current lr=0.0014596129757315068
# train loss: 0.510071, val loss: 1.245799, accuracy: 68.11, time:158.9537min
# ----------
# Epoch 179/349, current lr=0.0014461556960481275
# train loss: 0.508432, val loss: 1.248392, accuracy: 68.94, time:159.8727min
# ----------
# Epoch 180/349, current lr=0.0014327027544742289
# train loss: 0.507874, val loss: 1.264017, accuracy: 68.54, time:160.7796min
# ----------
# Epoch 181/349, current lr=0.0014192552348818088
# train loss: 0.533675, val loss: 1.311202, accuracy: 66.71, time:161.6862min
# ----------
# Epoch 182/349, current lr=0.001405814220706031
# train loss: 0.519238, val loss: 1.350555, accuracy: 64.88, time:162.6011min
# ----------
# Epoch 183/349, current lr=0.0013923807948579322
# train loss: 0.516719, val loss: 1.253819, accuracy: 68.55, time:163.5092min
# ----------
# Epoch 184/349, current lr=0.001378956039637175
# train loss: 0.511292, val loss: 1.259191, accuracy: 67.60, time:164.4166min
# ----------
# Epoch 185/349, current lr=0.001365541036644851
# train loss: 0.510670, val loss: 1.282940, accuracy: 67.66, time:165.3420min
# ----------
# Epoch 186/349, current lr=0.0013521368666963359
# train loss: 0.509157, val loss: 1.261536, accuracy: 67.39, time:166.2513min
# ----------
# Epoch 187/349, current lr=0.0013387446097342134
# train loss: 0.509998, val loss: 1.277612, accuracy: 67.88, time:167.1483min
# ----------
# Epoch 188/349, current lr=0.0013253653447412664
# train loss: 0.508756, val loss: 1.252190, accuracy: 67.74, time:168.0600min
# ----------
# Epoch 189/349, current lr=0.0013120001496535441
# train loss: 0.509637, val loss: 1.296579, accuracy: 66.09, time:168.9692min
# ----------
# Epoch 190/349, current lr=0.0012986501012735175
# train loss: 0.510365, val loss: 1.262922, accuracy: 67.60, time:169.8855min
# ----------
# Epoch 191/349, current lr=0.0012853162751833213
# train loss: 0.509131, val loss: 1.249829, accuracy: 67.81, time:170.8052min
# ----------
# Epoch 192/349, current lr=0.0012719997456580997
# train loss: 0.512230, val loss: 1.257826, accuracy: 68.08, time:171.7289min
# ----------
# Epoch 193/349, current lr=0.001258701585579453
# train loss: 0.508537, val loss: 1.276915, accuracy: 67.46, time:172.6402min
# ----------
# Epoch 194/349, current lr=0.001245422866348997
# train loss: 0.507765, val loss: 1.249431, accuracy: 67.99, time:173.5434min
# ----------
# Epoch 195/349, current lr=0.0012321646578020455
# train loss: 0.509593, val loss: 1.268912, accuracy: 67.24, time:174.4592min
# ----------
# Epoch 196/349, current lr=0.0012189280281214136
# train loss: 0.525794, val loss: 1.290252, accuracy: 67.06, time:175.3720min
# ----------
# Epoch 197/349, current lr=0.0012057140437513579
# train loss: 0.509760, val loss: 1.253927, accuracy: 67.83, time:176.2886min
# ----------
# Epoch 198/349, current lr=0.0011925237693116548
# train loss: 0.530406, val loss: 1.392137, accuracy: 64.19, time:177.1999min
# ----------
# Epoch 199/349, current lr=0.0011793582675118284
# train loss: 0.513905, val loss: 1.268267, accuracy: 68.10, time:178.1089min
# ----------
# Epoch 200/349, current lr=0.0011662185990655289
# train loss: 0.509939, val loss: 1.263830, accuracy: 68.39, time:179.0203min
# ----------
# Epoch 201/349, current lr=0.0011531058226050721
# train loss: 0.529289, val loss: 1.303183, accuracy: 65.12, time:179.9387min
# ----------
# Epoch 202/349, current lr=0.0011400209945961514
# train loss: 0.510525, val loss: 1.287691, accuracy: 66.45, time:180.8472min
# ----------
# Epoch 203/349, current lr=0.0011269651692527183
# train loss: 0.508017, val loss: 1.255597, accuracy: 67.77, time:181.7548min
# ----------
# Epoch 204/349, current lr=0.001113939398452047
# train loss: 0.508692, val loss: 1.259242, accuracy: 67.67, time:182.6692min
# ----------
# Epoch 205/349, current lr=0.0011009447316499877
# train loss: 0.507424, val loss: 1.276845, accuracy: 68.38, time:183.5766min
# ----------
# Epoch 206/349, current lr=0.0010879822157964152
# train loss: 0.506677, val loss: 1.258327, accuracy: 68.35, time:184.4916min
# ----------
# Epoch 207/349, current lr=0.0010750528952508764
# train loss: 0.507961, val loss: 1.261949, accuracy: 68.66, time:185.3859min
# ----------
# Epoch 208/349, current lr=0.0010621578116984502
# train loss: 0.510020, val loss: 1.280245, accuracy: 68.05, time:186.2753min
# ----------
# Epoch 209/349, current lr=0.0010492980040658223
# train loss: 0.509900, val loss: 1.297563, accuracy: 66.86, time:187.1726min
# ----------
# Epoch 210/349, current lr=0.0010364745084375793
# train loss: 0.508170, val loss: 1.298350, accuracy: 66.72, time:188.0659min
# ----------
# Epoch 211/349, current lr=0.001023688357972734
# train loss: 0.505541, val loss: 1.258591, accuracy: 67.97, time:188.9684min
# ----------
# Epoch 212/349, current lr=0.0010109405828214876
# train loss: 0.505698, val loss: 1.261387, accuracy: 68.17, time:189.8671min
# ----------
# Epoch 213/349, current lr=0.0009982322100422325
# train loss: 0.512042, val loss: 1.279272, accuracy: 67.10, time:190.7556min
# ----------
# Epoch 214/349, current lr=0.0009855642635188033
# train loss: 0.506043, val loss: 1.252275, accuracy: 67.54, time:191.6419min
# ----------
# Epoch 215/349, current lr=0.0009729377638779865
# train loss: 0.505368, val loss: 1.247519, accuracy: 69.10, time:192.5381min
# ----------
# Epoch 216/349, current lr=0.0009603537284072904
# train loss: 0.507686, val loss: 1.276779, accuracy: 67.05, time:193.4260min
# ----------
# Epoch 217/349, current lr=0.0009478131709729839
# train loss: 0.507986, val loss: 1.252065, accuracy: 68.69, time:194.3011min
# ----------
# Epoch 218/349, current lr=0.0009353171019384128
# train loss: 0.515599, val loss: 1.276869, accuracy: 68.00, time:195.1825min
# ----------
# Epoch 219/349, current lr=0.0009228665280825963
# train loss: 0.507455, val loss: 1.270704, accuracy: 68.16, time:196.0835min
# ----------
# Epoch 220/349, current lr=0.0009104624525191147
# train loss: 0.505944, val loss: 1.263577, accuracy: 67.66, time:196.9530min
# ----------
# Epoch 221/349, current lr=0.0008981058746152892
# train loss: 0.505763, val loss: 1.256120, accuracy: 67.27, time:197.8236min
# ----------
# Epoch 222/349, current lr=0.0008857977899116646
# train loss: 0.505036, val loss: 1.253575, accuracy: 68.17, time:198.6923min
# ----------
# Epoch 223/349, current lr=0.0008735391900418039
# train loss: 0.507258, val loss: 1.254252, accuracy: 68.62, time:199.5556min
# ----------
# Epoch 224/349, current lr=0.0008613310626523914
# train loss: 0.508690, val loss: 1.274045, accuracy: 68.44, time:200.4236min
# ----------
# Epoch 225/349, current lr=0.0008491743913236633
# train loss: 0.505495, val loss: 1.270410, accuracy: 68.19, time:201.2874min
# ----------
# Epoch 226/349, current lr=0.0008370701554901608
# train loss: 0.505406, val loss: 1.266909, accuracy: 68.26, time:202.1446min
# ----------
# Epoch 227/349, current lr=0.0008250193303618187
# train loss: 0.504804, val loss: 1.256949, accuracy: 68.23, time:203.0098min
# ----------
# Epoch 228/349, current lr=0.0008130228868453994
# train loss: 0.506251, val loss: 1.266761, accuracy: 68.14, time:203.8620min
# ----------
# Epoch 229/349, current lr=0.0008010817914662638
# train loss: 0.507759, val loss: 1.270187, accuracy: 67.26, time:204.7038min
# ----------
# Epoch 230/349, current lr=0.0007891970062905026
# train loss: 0.506229, val loss: 1.296312, accuracy: 66.61, time:205.5634min
# ----------
# Epoch 231/349, current lr=0.0007773694888474274
# train loss: 0.521022, val loss: 1.379220, accuracy: 62.84, time:206.4017min
# ----------
# Epoch 232/349, current lr=0.0007656001920524217
# train loss: 0.507235, val loss: 1.298135, accuracy: 66.75, time:207.2501min
# ----------
# Epoch 233/349, current lr=0.0007538900641301677
# train loss: 0.507768, val loss: 1.276269, accuracy: 67.69, time:208.0814min
# ----------
# Epoch 234/349, current lr=0.0007422400485382489
# train loss: 0.512177, val loss: 1.338120, accuracy: 65.92, time:208.9381min
# ----------
# Epoch 235/349, current lr=0.0007306510838911415
# train loss: 0.513838, val loss: 1.336101, accuracy: 66.35, time:209.7861min
# ----------
# Epoch 236/349, current lr=0.000719124103884588
# train loss: 0.507867, val loss: 1.285687, accuracy: 67.24, time:210.6246min
# ----------
# Epoch 237/349, current lr=0.0007076600372203741
# train loss: 0.507056, val loss: 1.282202, accuracy: 67.25, time:211.4803min
# ----------
# Epoch 238/349, current lr=0.0006962598075315059
# train loss: 0.506392, val loss: 1.277658, accuracy: 67.17, time:212.3379min
# ----------
# Epoch 239/349, current lr=0.0006849243333077924
# train loss: 0.505169, val loss: 1.266165, accuracy: 69.19, time:213.2189min
# ----------
# Epoch 240/349, current lr=0.000673654527821847
# train loss: 0.504005, val loss: 1.269190, accuracy: 67.80, time:214.0794min
# ----------
# Epoch 241/349, current lr=0.0006624512990555066
# train loss: 0.507920, val loss: 1.273078, accuracy: 67.76, time:214.9384min
# ----------
# Epoch 242/349, current lr=0.000651315549626679
# train loss: 0.504474, val loss: 1.282314, accuracy: 67.39, time:215.7993min
# ----------
# Epoch 243/349, current lr=0.0006402481767166175
# train loss: 0.505169, val loss: 1.278620, accuracy: 67.80, time:216.6602min
# ----------
# Epoch 244/349, current lr=0.0006292500719976404
# train loss: 0.506081, val loss: 1.267548, accuracy: 67.21, time:217.5259min
# ----------
# Epoch 245/349, current lr=0.0006183221215612912
# train loss: 0.504713, val loss: 1.269724, accuracy: 66.30, time:218.4088min
# ----------
# Epoch 246/349, current lr=0.0006074652058469454
# train loss: 0.507600, val loss: 1.265933, accuracy: 67.60, time:219.2664min
# ----------
# Epoch 247/349, current lr=0.0005966801995708774
# train loss: 0.505138, val loss: 1.262182, accuracy: 68.11, time:220.1416min
# ----------
# Epoch 248/349, current lr=0.0005859679716557887
# train loss: 0.504812, val loss: 1.265598, accuracy: 68.58, time:221.0267min
# ----------
# Epoch 249/349, current lr=0.000575329385160796
# train loss: 0.503940, val loss: 1.261454, accuracy: 67.83, time:221.9033min
# ----------
# Epoch 250/349, current lr=0.0005647652972119004
# train loss: 0.504824, val loss: 1.280516, accuracy: 67.04, time:222.7737min
# ----------
# Epoch 251/349, current lr=0.0005542765589329298
# train loss: 0.503254, val loss: 1.271312, accuracy: 67.70, time:223.6580min
# ----------
# Epoch 252/349, current lr=0.000543864015376966
# train loss: 0.504431, val loss: 1.272400, accuracy: 67.66, time:224.5457min
# ----------
# Epoch 253/349, current lr=0.0005335285054582593
# train loss: 0.505262, val loss: 1.267313, accuracy: 67.56, time:225.4379min
# ----------
# Epoch 254/349, current lr=0.0005232708618846402
# train loss: 0.504322, val loss: 1.277742, accuracy: 68.16, time:226.3302min
# ----------
# Epoch 255/349, current lr=0.0005130919110904317
# train loss: 0.503972, val loss: 1.309420, accuracy: 66.77, time:227.2350min
# ----------
# Epoch 256/349, current lr=0.0005029924731698625
# train loss: 0.504096, val loss: 1.276054, accuracy: 67.27, time:228.1337min
# ----------
# Epoch 257/349, current lr=0.0004929733618109946
# train loss: 0.503928, val loss: 1.272284, accuracy: 67.34, time:229.0531min
# ----------
# Epoch 258/349, current lr=0.00048303538423016964
# train loss: 0.502748, val loss: 1.262296, accuracy: 68.01, time:229.9616min
# ----------
# Epoch 259/349, current lr=0.00047317934110696803
# train loss: 0.504180, val loss: 1.277840, accuracy: 68.05, time:230.8647min
# ----------
# Epoch 260/349, current lr=0.00046340602651970367
# train loss: 0.502765, val loss: 1.261809, accuracy: 68.03, time:231.7635min
# ----------
# Epoch 261/349, current lr=0.00045371622788144744
# train loss: 0.504820, val loss: 1.292615, accuracy: 68.24, time:232.6805min
# ----------
# Epoch 262/349, current lr=0.0004441107258765833
# train loss: 0.504542, val loss: 1.293911, accuracy: 67.42, time:233.5876min
# ----------
# Epoch 263/349, current lr=0.0004345902943979152
# train loss: 0.503307, val loss: 1.280599, accuracy: 68.36, time:234.5039min
# ----------
# Epoch 264/349, current lr=0.0004251557004843122
# train loss: 0.502805, val loss: 1.265560, accuracy: 68.58, time:235.4240min
# ----------
# Epoch 265/349, current lr=0.0004158077042589134
# train loss: 0.503830, val loss: 1.272253, accuracy: 68.05, time:236.3462min
# ----------
# Epoch 266/349, current lr=0.0004065470588678836
# train loss: 0.504174, val loss: 1.272854, accuracy: 68.04, time:237.2530min
# ----------
# Epoch 267/349, current lr=0.00039737451041973543
# train loss: 0.502612, val loss: 1.272369, accuracy: 67.90, time:238.1716min
# ----------
# Epoch 268/349, current lr=0.0003882907979252186
# train loss: 0.505433, val loss: 1.276919, accuracy: 67.53, time:239.0833min
# ----------
# Epoch 269/349, current lr=0.00037929665323777637
# train loss: 0.503185, val loss: 1.274358, accuracy: 68.17, time:239.9965min
# ----------
# Epoch 270/349, current lr=0.00037039280099458423
# train loss: 0.504693, val loss: 1.289732, accuracy: 66.69, time:240.9188min
# ----------
# Epoch 271/349, current lr=0.00036157995855816736
# train loss: 0.503256, val loss: 1.278418, accuracy: 67.54, time:241.8238min
# ----------
# Epoch 272/349, current lr=0.00035285883595860285
# train loss: 0.502957, val loss: 1.270022, accuracy: 68.35, time:242.7380min
# ----------
# Epoch 273/349, current lr=0.00034423013583631675
# train loss: 0.504064, val loss: 1.267033, accuracy: 68.16, time:243.6588min
# ----------
# Epoch 274/349, current lr=0.0003356945533854709
# train loss: 0.503929, val loss: 1.271485, accuracy: 69.29, time:244.5700min
# ----------
# Epoch 275/349, current lr=0.0003272527762979557
# train loss: 0.504776, val loss: 1.258899, accuracy: 68.03, time:245.4786min
# ----------
# Epoch 276/349, current lr=0.0003189054847079827
# train loss: 0.502324, val loss: 1.280885, accuracy: 68.40, time:246.3903min
# ----------
# Epoch 277/349, current lr=0.0003106533511372875
# train loss: 0.503200, val loss: 1.257830, accuracy: 67.86, time:247.3207min
# ----------
# Epoch 278/349, current lr=0.00030249704044094843
# train loss: 0.503738, val loss: 1.282522, accuracy: 67.31, time:248.2328min
# ----------
# Epoch 279/349, current lr=0.00029443720975381765
# train loss: 0.504012, val loss: 1.275708, accuracy: 66.91, time:249.1553min
# ----------
# Epoch 280/349, current lr=0.0002864745084375794
# train loss: 0.503629, val loss: 1.274259, accuracy: 68.17, time:250.0774min
# ----------
# Epoch 281/349, current lr=0.00027860957802843276
# train loss: 0.502355, val loss: 1.283541, accuracy: 67.12, time:250.9865min
# ----------
# Epoch 282/349, current lr=0.0002708430521854029
# train loss: 0.502368, val loss: 1.265637, accuracy: 67.39, time:251.9231min
# ----------
# Epoch 283/349, current lr=0.00026317555663928906
# train loss: 0.503713, val loss: 1.258749, accuracy: 68.03, time:252.8274min
# ----------
# Epoch 284/349, current lr=0.00025560770914225363
# train loss: 0.503114, val loss: 1.293069, accuracy: 67.90, time:253.7332min
# ----------
# Epoch 285/349, current lr=0.0002481401194180464
# train loss: 0.504389, val loss: 1.303198, accuracy: 67.03, time:254.6457min
# ----------
# Epoch 286/349, current lr=0.00024077338911288447
# train loss: 0.502749, val loss: 1.328891, accuracy: 65.44, time:255.5607min
# ----------
# Epoch 287/349, current lr=0.00023350811174697777
# train loss: 0.503143, val loss: 1.269747, accuracy: 67.85, time:256.4734min
# ----------
# Epoch 288/349, current lr=0.00022634487266671015
# train loss: 0.503425, val loss: 1.272727, accuracy: 68.31, time:257.3760min
# ----------
# Epoch 289/349, current lr=0.0002192842489974794
# train loss: 0.502208, val loss: 1.274852, accuracy: 66.27, time:258.2963min
# ----------
# Epoch 290/349, current lr=0.0002123268095972012
# train loss: 0.502846, val loss: 1.282319, accuracy: 68.19, time:259.2175min
# ----------
# Epoch 291/349, current lr=0.00020547311501047504
# train loss: 0.503525, val loss: 1.272726, accuracy: 67.51, time:260.1432min
# ----------
# Epoch 292/349, current lr=0.00019872371742342396
# train loss: 0.506523, val loss: 1.298452, accuracy: 67.34, time:261.0566min
# ----------
# Epoch 293/349, current lr=0.0001920791606192068
# train loss: 0.502407, val loss: 1.284361, accuracy: 68.21, time:261.9707min
# ----------
# Epoch 294/349, current lr=0.0001855399799342049
# train loss: 0.502777, val loss: 1.269470, accuracy: 67.74, time:262.8806min
# ----------
# Epoch 295/349, current lr=0.00017910670221489328
# train loss: 0.502326, val loss: 1.273142, accuracy: 67.85, time:263.7827min
# ----------
# Epoch 296/349, current lr=0.0001727798457753925
# train loss: 0.504067, val loss: 1.277480, accuracy: 68.09, time:264.6965min
# ----------
# Epoch 297/349, current lr=0.00016655992035571047
# train loss: 0.502670, val loss: 1.280855, accuracy: 66.47, time:265.5988min
# ----------
# Epoch 298/349, current lr=0.0001604474270806723
# train loss: 0.503425, val loss: 1.268438, accuracy: 67.86, time:266.5253min
# ----------
# Epoch 299/349, current lr=0.0001544428584195472
# train loss: 0.506213, val loss: 1.271602, accuracy: 67.99, time:267.4210min
# ----------
# Epoch 300/349, current lr=0.00014854669814637168
# train loss: 0.503505, val loss: 1.255843, accuracy: 67.58, time:268.2733min
# ----------
# Epoch 301/349, current lr=0.0001427594213009712
# train loss: 0.502810, val loss: 1.288939, accuracy: 67.26, time:269.0784min
# ----------
# Epoch 302/349, current lr=0.0001370814941506885
# train loss: 0.502227, val loss: 1.280540, accuracy: 68.58, time:269.8751min
# ----------
# Epoch 303/349, current lr=0.00013151337415281877
# train loss: 0.501973, val loss: 1.304319, accuracy: 67.61, time:270.6956min
# ----------
# Epoch 304/349, current lr=0.00012605550991775055
# train loss: 0.503127, val loss: 1.268476, accuracy: 68.00, time:271.5048min
# ----------
# Epoch 305/349, current lr=0.00012070834117282435
# train loss: 0.505449, val loss: 1.268842, accuracy: 68.34, time:272.3244min
# ----------
# Epoch 306/349, current lr=0.00011547229872690426
# train loss: 0.503402, val loss: 1.274743, accuracy: 67.97, time:273.1369min
# ----------
# Epoch 307/349, current lr=0.00011034780443566902
# train loss: 0.503646, val loss: 1.279895, accuracy: 67.38, time:273.9447min
# ----------
# Epoch 308/349, current lr=0.00010533527116762317
# train loss: 0.503408, val loss: 1.269967, accuracy: 67.96, time:274.7498min
# ----------
# Epoch 309/349, current lr=0.00010043510277083385
# train loss: 0.505895, val loss: 1.276651, accuracy: 68.33, time:275.5674min
# ----------
# Epoch 310/349, current lr=9.564769404039436e-05
# train loss: 0.502496, val loss: 1.262823, accuracy: 67.99, time:276.3745min
# ----------
# Epoch 311/349, current lr=9.097343068661506e-05
# train loss: 0.502696, val loss: 1.270559, accuracy: 68.47, time:277.1750min
# ----------
# Epoch 312/349, current lr=8.641268930394807e-05
# train loss: 0.504178, val loss: 1.281612, accuracy: 67.56, time:277.9924min
# ----------
# Epoch 313/349, current lr=8.196583734064687e-05
# train loss: 0.502968, val loss: 1.298314, accuracy: 67.04, time:278.7977min
# ----------
# Epoch 314/349, current lr=7.763323306916085e-05
# train loss: 0.502580, val loss: 1.270145, accuracy: 67.60, time:279.6092min
# ----------
# Epoch 315/349, current lr=7.341522555726984e-05
# train loss: 0.502628, val loss: 1.268631, accuracy: 68.16, time:280.4575min
# ----------
# Epoch 316/349, current lr=6.931215463996201e-05
# train loss: 0.502949, val loss: 1.249937, accuracy: 68.50, time:281.3471min
# ----------
# Epoch 317/349, current lr=6.532435089205287e-05
# train loss: 0.502933, val loss: 1.265024, accuracy: 67.97, time:282.2300min
# ----------
# Epoch 318/349, current lr=6.145213560155178e-05
# train loss: 0.505057, val loss: 1.273108, accuracy: 67.64, time:283.1141min
# ----------
# Epoch 319/349, current lr=5.7695820743776824e-05
# train loss: 0.504044, val loss: 1.271449, accuracy: 67.92, time:284.0083min
# ----------
# Epoch 320/349, current lr=5.4055708956220244e-05
# train loss: 0.503132, val loss: 1.277025, accuracy: 67.35, time:284.8895min
# ----------
# Epoch 321/349, current lr=5.053209351416425e-05
# train loss: 0.502668, val loss: 1.276592, accuracy: 67.84, time:285.7642min
# ----------
# Epoch 322/349, current lr=4.7125258307053475e-05
# train loss: 0.502098, val loss: 1.273267, accuracy: 66.90, time:286.6408min
# ----------
# Epoch 323/349, current lr=4.3835477815622886e-05
# train loss: 0.502610, val loss: 1.268448, accuracy: 68.54, time:287.5136min
# ----------
# Epoch 324/349, current lr=4.0663017089782836e-05
# train loss: 0.502985, val loss: 1.266314, accuracy: 68.91, time:288.3787min
# ----------
# Epoch 325/349, current lr=3.760813172726464e-05
# train loss: 0.503454, val loss: 1.267686, accuracy: 67.83, time:289.2551min
# ----------
# Epoch 326/349, current lr=3.467106785302871e-05
# train loss: 0.504535, val loss: 1.277264, accuracy: 68.00, time:290.1193min
# ----------
# Epoch 327/349, current lr=3.185206209943292e-05
# train loss: 0.502720, val loss: 1.291380, accuracy: 67.34, time:290.9827min
# ----------
# Epoch 328/349, current lr=2.9151341587170028e-05
# train loss: 0.502038, val loss: 1.279093, accuracy: 67.96, time:291.8557min
# ----------
# Epoch 329/349, current lr=2.6569123906966965e-05
# train loss: 0.504725, val loss: 1.272791, accuracy: 67.69, time:292.7073min
# ----------
# Epoch 330/349, current lr=2.4105617102055708e-05
# train loss: 0.504714, val loss: 1.287236, accuracy: 66.85, time:293.5588min
# ----------
# Epoch 331/349, current lr=2.1761019651410013e-05
# train loss: 0.502359, val loss: 1.268473, accuracy: 67.45, time:294.4033min
# ----------
# Epoch 332/349, current lr=1.953552045375654e-05
# train loss: 0.502024, val loss: 1.294718, accuracy: 66.62, time:295.2450min
# ----------
# Epoch 333/349, current lr=1.742929881235403e-05
# train loss: 0.502065, val loss: 1.274421, accuracy: 68.29, time:296.0941min
# ----------
# Epoch 334/349, current lr=1.5442524420547693e-05
# train loss: 0.502262, val loss: 1.272417, accuracy: 68.20, time:296.9413min
# ----------
# Epoch 335/349, current lr=1.3575357348097974e-05
# train loss: 0.502121, val loss: 1.292360, accuracy: 66.88, time:297.7841min
# ----------
# Epoch 336/349, current lr=1.1827948028283206e-05
# train loss: 0.502686, val loss: 1.291560, accuracy: 67.39, time:298.6172min
# ----------
# Epoch 337/349, current lr=1.0200437245780809e-05
# train loss: 0.506042, val loss: 1.264313, accuracy: 68.69, time:299.4569min
# ----------
# Epoch 338/349, current lr=8.692956125322852e-06
# train loss: 0.502382, val loss: 1.272545, accuracy: 68.26, time:300.2973min
# ----------
# Epoch 339/349, current lr=7.305626121133181e-06
# train loss: 0.503166, val loss: 1.263512, accuracy: 67.97, time:301.1437min
# ----------
# Epoch 340/349, current lr=6.038559007141408e-06
# train loss: 0.502109, val loss: 1.270631, accuracy: 67.97, time:301.9914min
# ----------
# Epoch 341/349, current lr=4.891856867978115e-06
# train loss: 0.503998, val loss: 1.275444, accuracy: 67.53, time:302.8332min
# ----------
# Epoch 342/349, current lr=3.865612090748933e-06
# train loss: 0.502336, val loss: 1.290130, accuracy: 67.59, time:303.7039min
# ----------
# Epoch 343/349, current lr=2.9599073575926666e-06
# train loss: 0.501747, val loss: 1.285532, accuracy: 67.19, time:304.5640min
# ----------
# Epoch 344/349, current lr=2.174815639018616e-06
# train loss: 0.504100, val loss: 1.262575, accuracy: 67.53, time:305.4239min
# ----------
# Epoch 345/349, current lr=1.5104001880281183e-06
# train loss: 0.503071, val loss: 1.266672, accuracy: 68.21, time:306.2915min
# ----------
# Epoch 346/349, current lr=9.667145350179555e-07
# train loss: 0.502073, val loss: 1.284445, accuracy: 67.07, time:307.1586min
# ----------
# Epoch 347/349, current lr=5.438024834683039e-07
# train loss: 0.502119, val loss: 1.272609, accuracy: 68.24, time:308.0221min
# ----------
# Epoch 348/349, current lr=2.4169810641272476e-07
# train loss: 0.502108, val loss: 1.293483, accuracy: 67.46, time:308.8920min
# ----------
# Epoch 349/349, current lr=6.042574369335983e-08
# train loss: 0.502378, val loss: 1.278577, accuracy: 68.35, time:309.7848min
# ----------

# %%
# Train-Validation Progress
num_epochs = params_train["num_epochs"]

# plot loss progress
plt.title("Train-Val Loss")
plt.plot(range(1, num_epochs+1), loss_hist["train"], label="train")
plt.plot(range(1, num_epochs+1), loss_hist["val"], label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("Train-Val Accuracy")
plt.plot(range(1,num_epochs+1), metric_hist["train"], label="train")
plt.plot(range(1, num_epochs+1), metric_hist["val"], label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# %%
print(f'최종 val accuracy: {100*metric_hist["val"][-1]:.2f}%')
print(f'최고 val accuracy: {100*max(metric_hist["val"]):.2f}%')
# Out:
# 최종 val accuracy: 68.35%
# 최고 val accuracy: 70.21%
